# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshreddy101/news_paper/blob/main/EDA_1_Latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data_clean (1).csv")
data.head(10)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5           6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6           7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7           8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8           9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9          10    NaN    194.0   8.6     69     5   10  2010    69       S

# %%
data.shape
# Out:
# (158, 10)

# %%
data1.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
#Data Structure
type(data)
data.shape
# Out:
# (158, 10)

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# # Data type conversion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data1=data.iloc[:,1:]

# %%
data1
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#The method .copy() is used here so that any changes made in new DataFrame don't get reflected in the original one
data=data2.copy()

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   157 non-null    float64
#  4   Month    157 non-null    float64
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    category
# dtypes: category(1), float64(5), int64(3)
# memory usage: 10.3 KB

# %% [markdown]
# # Duplicates

# %%
#Count of duplicated rows
data[data.duplicated()].shape
# Out:
# (1, 9)

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#Print the duplicated rows
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0    9.0   28  2010    75       S

# %%
data_cleaned1=data.drop_duplicates()

# %%
data_cleaned1.shape
# Out:
# (157, 9)

# %% [markdown]
# # Drop columns

# %%
data_cleaned2=data_cleaned1.drop('Year',axis=1)

# %%
data_cleaned2
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Temp Weather
# 0     41.0    190.0   7.4    67.0    5.0    1    67       S
# 1     36.0    118.0   8.0    72.0    5.0    2    72       C
# 2     12.0    149.0  12.6    74.0    5.0    3    74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4    62       S
# 4      NaN      NaN  14.3    56.0    5.0    5    56       S
# ..     ...      ...   ...     ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5    68.0    9.0   30    68       S
# 153   41.0    190.0   7.4    67.0    5.0    1    67       C
# 154   30.0    193.0   6.9    70.0    9.0   26    70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27    77       S
# 157   18.0    131.0   8.0    76.0    9.0   29    76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar.R  150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Temp C   156 non-null    float64
#  4   Month    156 non-null    float64
#  5   Day      157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(5), int64(2)
# memory usage: 10.1 KB

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data_cleaned1 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)
data_cleaned1 = data_cleaned2.rename({'Temp': 'Temparature'}, axis=1)

# %%
data_cleaned1
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Temparature Weather
# 0     41.0    190.0   7.4    67.0    5.0    1           67       S
# 1     36.0    118.0   8.0    72.0    5.0    2           72       C
# 2     12.0    149.0  12.6    74.0    5.0    3           74      PS
# 3     18.0    313.0  11.5    62.0    5.0    4           62       S
# 4      NaN      NaN  14.3    56.0    5.0    5           56       S
# ..     ...      ...   ...     ...    ...  ...          ...     ...
# 152   20.0    223.0  11.5    68.0    9.0   30           68       S
# 153   41.0    190.0   7.4    67.0    5.0    1           67       C
# 154   30.0    193.0   6.9    70.0    9.0   26           70      PS
# 155    NaN    145.0  13.2    77.0    9.0   27           77       S
# 157   18.0    131.0   8.0    76.0    9.0   29           76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned1.shape
# Out:
# (157, 8)

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
data_cleaned1['Ozone'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
#plt.boxplot(data_cleaned1['Ozone'])
plt.boxplot(data_cleaned1['Wind'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a8b0417f9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a8b0417fe80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a8b0417f730>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a8b041b0400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a8b041b06a0>],
#  'means': []}

# %%
#Extracting the outliersC

# %%
out=[]
for item in box['fliers']:
    out.append(item.get_ydata())
out
# Out:
# [array([], dtype=float64)]

# %%
#to get whiskers
[item.get_ydata()[1] for item in box['whiskers']]
# Out:
# [1.0, 80.0]

# %%
#descriptive stat
data_cleaned1['Wind'].describe()
# Out:
# count    155.000000
# mean      17.570323
# std       21.488252
# min        1.700000
# 25%        8.000000
# 50%       10.300000
# 75%       14.300000
# max       80.000000
# Name: Wind, dtype: float64

# %%
data_cleaned1.loc[(data_cleaned1.Wind>80) | (data_cleaned1.Wind<0)]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Temparature, Weather]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# ...

# %%
data_cleaned1['Wind'] = pd.to_numeric(data_cleaned1['Wind'])

# %%
#camping and flooring
#data_cleaned1.loc[data_cleaned1.Ozone>80, 'Ozone']=80
data_cleaned1.loc[data_cleaned1.Ozone>80, 'Wind']=80

# %%
data_cleaned1.describe()
# Out:
#             Ozone     Solar.R        Wind      Temp C       Month         Day  \
# count  155.000000  155.000000  155.000000  155.000000  155.000000  155.000000
# mean    36.858065  170.556903   17.570323   76.929032   14.522581   22.522581
# std     22.287507   91.083376   21.488252    8.468513   22.329683   21.226770
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     21.000000   80.000000    8.000000   72.000000    6.000000   10.000000
# 50%     31.000000  175.000000   10.300000   79.000000    7.000000   18.000000
# 75%     45.500000  252.500000   14.300000   82.000000    9.000000   26.000000
# max     80.000000  334.000000   80.000000   97.000000   80.000000   80.000000
#
#        Temparature
# count   155.000000
# mean     76.929032
# std       8.468513
# min      56.000000
# 25%      72.000000
# 50%      79.000000
# 75%      82.000000
# max      97.000000

# %%
#plt.boxplot(data_cleaned1.Ozone)
plt.boxplot(data_cleaned1.Wind)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a8afffaa2c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a8afffaa800>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a8afffaa020>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a8afffaad40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a8afffaafe0>],
#  'means': []}

# %%
#Descriptive stat
data_cleaned1['Wind'].describe()
# Out:
# count    155.000000
# mean      17.570323
# std       21.488252
# min        1.700000
# 25%        8.000000
# 50%       10.300000
# 75%       14.300000
# max       80.000000
# Name: Wind, dtype: float64

# %%
data_cleaned1
# Out:
#      Ozone     Solar.R  Wind  Temp C  Month  Day  Temparature Weather
# 0     41.0  190.000000   7.4    67.0    5.0    1           67       S
# 1     36.0  118.000000   8.0    72.0    5.0    2           72       C
# 2     12.0  149.000000  12.6    74.0    5.0    3           74      PS
# 3     18.0  313.000000  11.5    62.0    5.0    4           62       S
# 4     31.0  170.053333  14.3    56.0    5.0    5           56       S
# ..     ...         ...   ...     ...    ...  ...          ...     ...
# 152   20.0  223.000000  11.5    68.0    9.0   30           68       S
# 153   41.0  190.000000   7.4    67.0    5.0    1           67       C
# 154   30.0  193.000000   6.9    70.0    9.0   26           70      PS
# 155   31.0  145.000000  13.2    77.0    9.0   27           77       S
# 157   18.0  131.000000   8.0    76.0    9.0   29           76       C
#
# [155 rows x 8 columns]

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Weather'>

# %% [markdown]
# # Missing Values and Imputation

# %%
import seaborn as sns
cols = data_cleaned1.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned1[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
data_cleaned1[data_cleaned1.isnull().any(axis=1)].head()
# Out:
#     Ozone  Solar.R  Wind  Temp C  Month  Day  Temparature Weather
# 4     NaN      NaN  14.3    56.0    5.0    5           56       S
# 5    28.0      NaN  14.9    66.0    5.0    6           66       C
# 9     NaN    194.0   8.6    69.0    5.0   10           69       S
# 10    7.0      NaN   6.9     NaN    5.0   11           74       C
# 23   32.0     92.0  12.0    61.0    NaN   24           61       C

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          38
# Solar.R         7
# Wind            0
# Temp C          1
# Month           1
# Day             0
# Temparature     0
# Weather         3
# dtype: int64

# %%
#Mean Imputation
median = data_cleaned1['Ozone'].median()
print(median)
# Out:
# 31.0

# %%
data_cleaned1['Ozone'] = data_cleaned1['Ozone'].fillna(median)

# %%
mean = data_cleaned1['Solar.R'].mean()
print(mean)
# Out:
# 170.05333333333334

# %%
data_cleaned1['Solar.R'] = data_cleaned1['Solar.R'].fillna(mean)

# %%
data_cleaned1
# Out:
#      Ozone     Solar.R  Wind  Temp C  Month  Day  Temparature Weather
# 0     41.0  190.000000   7.4    67.0    5.0    1           67       S
# 1     36.0  118.000000   8.0    72.0    5.0    2           72       C
# 2     12.0  149.000000  12.6    74.0    5.0    3           74      PS
# 3     18.0  313.000000  11.5    62.0    5.0    4           62       S
# 4     31.0  170.053333  14.3    56.0    5.0    5           56       S
# ..     ...         ...   ...     ...    ...  ...          ...     ...
# 152   20.0  223.000000  11.5    68.0    9.0   30           68       S
# 153   41.0  190.000000   7.4    67.0    5.0    1           67       C
# 154   30.0  193.000000   6.9    70.0    9.0   26           70      PS
# 155   31.0  145.000000  13.2    77.0    9.0   27           77       S
# 157   18.0  131.000000   8.0    76.0    9.0   29           76       C
#
# [157 rows x 8 columns]

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        157 non-null    float64
#  1   Solar.R      157 non-null    float64
#  2   Wind         157 non-null    float64
#  3   Temp C       156 non-null    float64
#  4   Month        156 non-null    float64
#  5   Day          157 non-null    int64
#  6   Temparature  157 non-null    int64
#  7   Weather      154 non-null    category
# dtypes: category(1), float64(5), int64(2)
# memory usage: 10.1 KB

# %%
mode_weather = data_cleaned1.Weather.mode()[0]
print(mode_weather)
# Out:
# S

# %%
data_cleaned1['Weather'] =data_cleaned1.Weather.fillna(mode_weather)

# %%
data_cleaned1.isnull().sum()
# Out:
# Ozone          0
# Solar.R        0
# Wind           0
# Temp C         1
# Month          1
# Day            0
# Temparature    0
# Weather        0
# dtype: int64

# %%
data_cleaned1.dropna(inplace=True)

# %%
data_cleaned1['Weather'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Weather'>

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
 # Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(data_cleaned3)

# %%
#Correlation
#Correlation
data_cleaned1.corr(numeric_only=True) # Add numeric_only=True to only include numeric columns
data_cleaned1.corr()

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data,columns=['Weather'])

# %%
data_cleaned4

# %%
data_cleaned4=data_cleaned4.dropna()

# %% [markdown]
# #### Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values

# %%
array = data_cleaned3.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
